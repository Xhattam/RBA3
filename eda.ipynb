# %%
import pandas as pd

# %%
df = pd.read_csv("data/sample_data.csv")

# %%
df
# Out:
#           PRESERVICA_CSV_TEMPLATE  \
# 0             file or folder name
# 1  Current name of file or folder
# 2                             014
#
#   http://www.openarchives.org/OAI/2.0/oai_dc/;//dc:title  \
# 0                                              Title
# 1                              Description of record
# 2    Photograph of loading bay from Old Civic Centre
#
#   http://www.openarchives.org/OAI/2.0/oai_dc/;//dc:creator  \
# 0                                            Creator
# 1                The creator of the record, if known
# 2                                       Peter Markus
#
#   http://www.openarchives.org/OAI/2.0/oai_dc/;//dc:subject  \
# 0                                            Subject
# 1  A one word subject, not included in title, whi...
# 2                                                Van
#
#   http://www.openarchives.org/OAI/2.0/oai_dc/;//dc:description  \
# 0                                        Description
# ...

# %%
df.iloc[0].values
# Out:
# <StringArray>
# ['file or folder name',               'Title',             'Creator',
#              'Subject',         'Description',           'Publisher',
#          'Contributor',                'Date',                'Type',
#               'Format',          'Identifier',              'Source',
#             'Language',            'Relation',            'Coverage',
#               'Rights']
# Length: 16, dtype: str
